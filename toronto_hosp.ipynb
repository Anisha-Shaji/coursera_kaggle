# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('covid-19-immunization-clinics.csv')

# %%
df.head()
# Out:
#      _id  locationId                      locationName  \
# 0  17454       156.0                        The Hangar
# 1  17455       157.0           Scarborough Town Centre
# 2  17456       152.0  Carmine Stefano Community Centre
# 3  17457       158.0                   Cloverdale Mall
# 4  17458       150.0              Mitchell Field Arena
#
#                         locationType            address city postal_code  \
# 0  City-operated Immunization Clinic  75 Carl Hall Road  NaN         NaN
# 1  City-operated Immunization Clinic  300 Borough Drive  NaN         NaN
# 2  City-operated Immunization Clinic   3100 Weston Road  NaN         NaN
# 3  City-operated Immunization Clinic  250 The East Mall  NaN         NaN
# 4  City-operated Immunization Clinic   89 Church Avenue  NaN         NaN
#
#    addressInfo  lat       long  ...  Thursday_Closed Friday_Open  \
# 0          NaN  NaN -79.473832  ...              NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['_id', 'locationId', 'locationName', 'locationType', 'address', 'city',
#        'postal_code', 'addressInfo', 'lat', 'long', 'dates', 'hours', 'info',
#        'phone', 'phoneExt', 'phoneAlt', 'phoneAltExt', 'website',
#        'accessibility', 'sameDayAppt', 'active', 'temporarily_closed',
#        'pharmacy', 'operated_by', 'location_name_fr', 'operated_by_fr',
#        'address_fr', 'province', 'PHU', 'PHU_fr', 'monday', 'tuesday',
#        'wednesday', 'thursday', 'friday', 'saturday', 'sunday', 'appointments',
#        'online_appointments', 'phone_appointments', 'walk_ins', 'symptomatic',
#        'drive_through', 'general_population', 'children_under_2',
#        'age_threshold', 'weeks_pregnant', 'french_language_services',
#        'accessible', 'asl_interpretation', 'first_nations', 'free_parking',
#        'paid_parking', 'public_transit', 'additional_information',
#        'additional_information_fr', 'Monday_Open', 'Monday_Closed',
# ...

# %%
df_nan_col = []

# %%
for  i in df.columns:
     print(i)
     print(df[i].unique())
     if len(df[i].unique())==1  :
        df_nan_col.append(i)
# Out:
# _id
# [17454 17455 17456 17457 17458 17459 17460 17461 17462 17463 17464 17465
#  17466 17467 17468 17469 17470 17471 17472 17473 17474 17475 17476 17477
#  17478 17479 17480 17481 17482 17483 17484 17485 17486 17487 17488 17489
#  17490 17491 17492 17493 17494 17495 17496 17497 17498 17499 17500 17501
#  17502 17503 17504 17505 17506 17507 17508 17509 17510 17511 17512 17513
#  17514 17515 17516 17517 17518 17519 17520 17521 17522 17523 17524 17525
#  17526 17527 17528 17529 17530 17531 17532 17533 17534 17535 17536 17537
#  17538 17539 17540 17541 17542 17543 17544 17545 17546 17547 17548 17549
#  17550 17551 17552 17553 17554 17555 17556 17557 17558 17559 17560 17561
#  17562 17563 17564 17565 17566 17567 17568 17569 17570 17571 17572 17573
#  17574 17575 17576 17577 17578 17579 17580 17581 17582 17583 17584 17585
#  17586 17587 17588 17589 17590 17591 17592 17593 17594 17595 17596 17597
#  17598 17599 17600 17601 17602 17603 17604 17605 17606 17607 17608 17609
# ...

# %%
df_nan_col
# Out:
# ['addressInfo',
#  'lat',
#  'dates',
#  'phoneExt',
#  'phoneAlt',
#  'phoneAltExt',
#  'accessibility',
#  'sameDayAppt',
#  'active',
#  'temporarily_closed',
#  'pharmacy',
#  'operated_by',
#  'location_name_fr',
#  'operated_by_fr',
#  'address_fr',
#  'province',
#  'PHU',
#  'PHU_fr',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'friday',
#  'saturday',
#  'sunday',
#  'appointments',
#  'online_appointments',
#  'phone_appointments',
#  'walk_ins',
#  'symptomatic',
#  'drive_through',
#  'general_population',
#  'children_under_2',
#  'age_threshold',
#  'weeks_pregnant',
#  'french_language_services',
#  'accessible',
#  'asl_interpretation',
#  'first_nations',
#  'free_parking',
#  'paid_parking',
#  'public_transit',
#  'additional_information',
#  'additional_information_fr',
#  'Monday_Open',
#  'Monday_Closed',
#  'Tuesday_Open',
#  'Tuesday_Closed',
#  'Wednesday_Open',
#  'Wednesday_Closed',
#  'Thursday_Open',
#  'Thursday_Closed',
# ...

# %%
for  i in df_nan_col:
     print(i)
     print(df[i].unique())
# Out:
# addressInfo
# [nan]
# lat
# [nan]
# dates
# [nan]
# phoneExt
# [nan]
# phoneAlt
# [nan]
# phoneAltExt
# [nan]
# accessibility
# [nan]
# sameDayAppt
# [nan]
# active
# [nan]
# temporarily_closed
# [nan]
# pharmacy
# [nan]
# operated_by
# [nan]
# location_name_fr
# [nan]
# operated_by_fr
# [nan]
# address_fr
# [nan]
# province
# [nan]
# PHU
# [nan]
# PHU_fr
# [nan]
# monday
# [nan]
# tuesday
# [nan]
# wednesday
# [nan]
# thursday
# [nan]
# friday
# [nan]
# saturday
# [nan]
# sunday
# [nan]
# appointments
# [nan]
# online_appointments
# [nan]
# phone_appointments
# [nan]
# walk_ins
# [nan]
# symptomatic
# [nan]
# drive_through
# [nan]
# general_population
# [nan]
# children_under_2
# [nan]
# age_threshold
# [nan]
# weeks_pregnant
# [nan]
# french_language_services
# [nan]
# accessible
# [nan]
# asl_interpretation
# [nan]
# first_nations
# [nan]
# free_parking
# [nan]
# paid_parking
# [nan]
# public_transit
# [nan]
# additional_information
# [nan]
# additional_information_fr
# [nan]
# ...

# %%
for i in df_nan_col:
    df=df.drop([i], axis = 1)

# %%
df.head()
# Out:
#      _id  locationId                      locationName  \
# 0  17454       156.0                        The Hangar
# 1  17455       157.0           Scarborough Town Centre
# 2  17456       152.0  Carmine Stefano Community Centre
# 3  17457       158.0                   Cloverdale Mall
# 4  17458       150.0              Mitchell Field Arena
#
#                         locationType            address city postal_code  \
# 0  City-operated Immunization Clinic  75 Carl Hall Road  NaN         NaN
# 1  City-operated Immunization Clinic  300 Borough Drive  NaN         NaN
# 2  City-operated Immunization Clinic   3100 Weston Road  NaN         NaN
# 3  City-operated Immunization Clinic  250 The East Mall  NaN         NaN
# 4  City-operated Immunization Clinic   89 Church Avenue  NaN         NaN
#
#         long              hours                                    info phone  \
# 0 -79.473832  11 a.m. to 8 p.m.                    By appointment only.   NaN
# ...

# %%
for  i in df.columns:
     print(i)
     print(df[i].unique())
# Out:
# _id
# [17454 17455 17456 17457 17458 17459 17460 17461 17462 17463 17464 17465
#  17466 17467 17468 17469 17470 17471 17472 17473 17474 17475 17476 17477
#  17478 17479 17480 17481 17482 17483 17484 17485 17486 17487 17488 17489
#  17490 17491 17492 17493 17494 17495 17496 17497 17498 17499 17500 17501
#  17502 17503 17504 17505 17506 17507 17508 17509 17510 17511 17512 17513
#  17514 17515 17516 17517 17518 17519 17520 17521 17522 17523 17524 17525
#  17526 17527 17528 17529 17530 17531 17532 17533 17534 17535 17536 17537
#  17538 17539 17540 17541 17542 17543 17544 17545 17546 17547 17548 17549
#  17550 17551 17552 17553 17554 17555 17556 17557 17558 17559 17560 17561
#  17562 17563 17564 17565 17566 17567 17568 17569 17570 17571 17572 17573
#  17574 17575 17576 17577 17578 17579 17580 17581 17582 17583 17584 17585
#  17586 17587 17588 17589 17590 17591 17592 17593 17594 17595 17596 17597
#  17598 17599 17600 17601 17602 17603 17604 17605 17606 17607 17608 17609
# ...

# %%
 df=df.drop(['_id'], axis = 1)

# %%
x=df.geometry.apply(pd.Series)

# %%
df['geometry'] = df['geometry']. str.replace('u', '')

# %%
x= df['geometry'].str.split(",", n = 1, expand = True)

# %%
co_ordinates=x[1]

# %%
x[1]
# Out:
# 0         'coordinates': (-79.473832254, 43.748094044)}
# 1       'coordinates': (-79.2589306154, 43.7769902318)}
# 2       'coordinates': (-79.5392227326, 43.7331551777)}
# 3       'coordinates': (-79.5565019596, 43.6326036122)}
# 4        'coordinates': (-79.408229002, 43.7746375589)}
#                              ...
# 302        'coordinates': (-79.464139811, 43.73150664)}
# 303       'coordinates': (-79.495848285, 43.689037346)}
# 304       'coordinates': (-79.489438365, 43.614273804)}
# 305       'coordinates': (-79.351481872, 43.706587121)}
# 306        'coordinates': (-79.226358939, 43.79570521)}
# Name: 1, Length: 307, dtype: object

# %%
co_ordinates=x[1].str.strip("u'coordinates': ()}")

# %%
co_ordinates
# Out:
# 0        -79.473832254, 43.748094044
# 1      -79.2589306154, 43.7769902318
# 2      -79.5392227326, 43.7331551777
# 3      -79.5565019596, 43.6326036122
# 4       -79.408229002, 43.7746375589
#                    ...
# 302       -79.464139811, 43.73150664
# 303      -79.495848285, 43.689037346
# 304      -79.489438365, 43.614273804
# 305      -79.351481872, 43.706587121
# 306       -79.226358939, 43.79570521
# Name: 1, Length: 307, dtype: object

# %%
co_ordinates = co_ordinates.str.split(",", n = 1, expand = True)

# %%
co_ordinates.head()
# Out:
#                 0               1
# 0   -79.473832254    43.748094044
# 1  -79.2589306154   43.7769902318
# 2  -79.5392227326   43.7331551777
# 3  -79.5565019596   43.6326036122
# 4   -79.408229002   43.7746375589

# %%
 co_ordinates = co_ordinates.rename(columns = {0 : 'longitude', 1 : 'latitude'}, inplace = False )

# %%
 co_ordinates.head()
# Out:
#         longitude        latitude
# 0   -79.473832254    43.748094044
# 1  -79.2589306154   43.7769902318
# 2  -79.5392227326   43.7331551777
# 3  -79.5565019596   43.6326036122
# 4   -79.408229002   43.7746375589

# %%
df_out= pd.concat([df, co_ordinates], axis=1)

# %%
df_out.head()
# Out:
#    locationId                      locationName  \
# 0       156.0                        The Hangar
# 1       157.0           Scarborough Town Centre
# 2       152.0  Carmine Stefano Community Centre
# 3       158.0                   Cloverdale Mall
# 4       150.0              Mitchell Field Arena
#
#                         locationType            address city postal_code  \
# 0  City-operated Immunization Clinic  75 Carl Hall Road  NaN         NaN
# 1  City-operated Immunization Clinic  300 Borough Drive  NaN         NaN
# 2  City-operated Immunization Clinic   3100 Weston Road  NaN         NaN
# 3  City-operated Immunization Clinic  250 The East Mall  NaN         NaN
# 4  City-operated Immunization Clinic   89 Church Avenue  NaN         NaN
#
#         long              hours                                    info phone  \
# 0 -79.473832  11 a.m. to 8 p.m.                    By appointment only.   NaN
# ...

# %%
df_out=df_out.drop(['long'], axis = 1)

# %%
df_out.head()
# Out:
#    locationId                      locationName  \
# 0       156.0                        The Hangar
# 1       157.0           Scarborough Town Centre
# 2       152.0  Carmine Stefano Community Centre
# 3       158.0                   Cloverdale Mall
# 4       150.0              Mitchell Field Arena
#
#                         locationType            address city postal_code  \
# 0  City-operated Immunization Clinic  75 Carl Hall Road  NaN         NaN
# 1  City-operated Immunization Clinic  300 Borough Drive  NaN         NaN
# 2  City-operated Immunization Clinic   3100 Weston Road  NaN         NaN
# 3  City-operated Immunization Clinic  250 The East Mall  NaN         NaN
# 4  City-operated Immunization Clinic   89 Church Avenue  NaN         NaN
#
#                hours                                    info phone website  \
# 0  11 a.m. to 8 p.m.                    By appointment only.   NaN     NaN
# 1  11 a.m. to 8 p.m.                    By appointment only.   NaN     NaN
# ...

# %%
df_out=df_out.drop(['locationId','OBJECTID','phone'], axis = 1)

# %%
df_out
# Out:
#                          locationName                       locationType  \
# 0                          The Hangar  City-operated Immunization Clinic
# 1             Scarborough Town Centre  City-operated Immunization Clinic
# 2    Carmine Stefano Community Centre  City-operated Immunization Clinic
# 3                     Cloverdale Mall  City-operated Immunization Clinic
# 4                Mitchell Field Arena  City-operated Immunization Clinic
# ..                                ...                                ...
# 302                Nhatrang Drug Mart         Pharmacy Immunization Site
# 303              Weston jane Pharmacy         Pharmacy Immunization Site
# 304                 Lakeside Pharmacy         Pharmacy Immunization Site
# 305          I CARE Pharmacy Services         Pharmacy Immunization Site
# 306                  Lapsley Pharmacy         Pharmacy Immunization Site
#
#                                   address       city postal_code  \
# ...

# %%
df_out.head()
# Out:
#                        locationName                       locationType  \
# 0                        The Hangar  City-operated Immunization Clinic
# 1           Scarborough Town Centre  City-operated Immunization Clinic
# 2  Carmine Stefano Community Centre  City-operated Immunization Clinic
# 3                   Cloverdale Mall  City-operated Immunization Clinic
# 4              Mitchell Field Arena  City-operated Immunization Clinic
#
#              address city postal_code              hours  \
# 0  75 Carl Hall Road  NaN         NaN  11 a.m. to 8 p.m.
# 1  300 Borough Drive  NaN         NaN  11 a.m. to 8 p.m.
# 2   3100 Weston Road  NaN         NaN                NaN
# 3  250 The East Mall  NaN         NaN                NaN
# 4   89 Church Avenue  NaN         NaN  11 a.m. to 8 p.m.
#
#                                      info website  \
# 0                    By appointment only.     NaN
# 1                    By appointment only.     NaN
# ...

# %%
df_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   locationName  307 non-null    object
#  1   locationType  307 non-null    object
#  2   address       307 non-null    object
#  3   city          276 non-null    object
#  4   postal_code   276 non-null    object
#  5   hours         282 non-null    object
#  6   info          307 non-null    object
#  7   website       272 non-null    object
#  8   Data_Source   307 non-null    object
#  9   geometry      307 non-null    object
#  10  longitude     307 non-null    object
#  11  latitude      307 non-null    object
# dtypes: object(12)
# memory usage: 28.9+ KB

# %%
df_out.dropna(subset = ['city'], inplace=True)

# %%
df_out.latitude.unique()
# Out:
# array([' 43.70791816', ' 43.708746567', ' 43.75669264', ' 43.685625102',
#        ' 43.738836382', ' 43.686772181', ' 43.735377559', ' 43.758778536',
#        ' 43.734787027', ' 43.688674585', ' 43.667222854', ' 43.7729758',
#        ' 43.663087211', ' 43.702148362', ' 43.669556461', ' 43.656558446',
#        ' 43.651021745', ' 43.643375049', ' 43.721575079', ' 43.722676877',
#        ' 43.68395699', ' 43.630166261', ' 43.682747376', ' 43.708950967',
#        ' 43.699241101', ' 43.70047591', ' 43.707775578', ' 43.772890602',
#        ' 43.661232463', ' 43.674934792', ' 43.640261296', ' 43.715201537',
#        ' 43.809220727', ' 43.754567819', ' 43.784135226', ' 43.650413472',
#        ' 43.832776635', ' 43.65427804', ' 43.788621397', ' 43.705538116',
#        ' 43.728254536', ' 43.725155934', ' 43.64632013', ' 43.695808882',
#        ' 43.748649471', ' 43.665870051', ' 43.66664672', ' 43.661814113',
#        ' 43.649891591', ' 43.647503698', ' 43.711375082', ' 43.650929345',
# ...

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Folium installed
# Libraries imported.

# %%
#CLIENT_ID = 'KWKBSQ0MNO4IHZGBYIQHBEQPC5B2TEIDTSRYBBLYNTJAFPT1' # your Foursquare ID
#CLIENT_SECRET = 'QR04DE3H0M5ITS3CUNMEJSZOPTBFBVH2TLIIWPSYVQME1ABO' # your Foursquare Secret

CLIENT_ID = 'KWKBSQ0MNO4IHZGBYIQHBEQPC5B2TEIDTSRYBBLYNTJAFPT1'
CLIENT_SECRET = 'B5LVZ53K1DMPANFIP43ULPFPTDARD5AJMGAHMMTTHRMXIJWL'
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20210425'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KWKBSQ0MNO4IHZGBYIQHBEQPC5B2TEIDTSRYBBLYNTJAFPT1
# CLIENT_SECRET:B5LVZ53K1DMPANFIP43ULPFPTDARD5AJMGAHMMTTHRMXIJWL

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
#url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KWKBSQ0MNO4IHZGBYIQHBEQPC5B2TEIDTSRYBBLYNTJAFPT1&client_secret=B5LVZ53K1DMPANFIP43ULPFPTDARD5AJMGAHMMTTHRMXIJWL&ll=43.6534817,-79.3839347&oauth_token=&v=20210425'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60997d077f1d5a5be5137e13'},
#  'response': {'venues': [{'id': '5b193c42598e64002ca79b96',
#     'name': 'City of Toronto Civic Innovation Office',
#     'location': {'address': '100 Queen St W',
#      'lat': 43.653454,
#      'lng': -79.383952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653454,
#        'lng': -79.383952}],
#      'distance': 3,
#      'postalCode': 'M5H 2N2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Queen St W', 'Toronto ON M5H 2N2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d129941735',
#       'name': 'City Hall',
#       'pluralName': 'City Halls',
#       'shortName': 'City Hall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/cityhall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1620671751',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe
# Out:
#                           id                                          name  \
# 0   5b193c42598e64002ca79b96       City of Toronto Civic Innovation Office
# 1   4ad4c05ef964a5208ff620e3                             Toronto City Hall
# 2   4c41d47cd691c9b6fa4c8d0a                        Kew Gardens Playground
# 3   4c0121fd9a950f47fa9208c6                   City Hall Podium Green Roof
# 4   4c093ee0340720a153728493                    City Hall Council Chambers
# 5   4e4a878c52b11cf651b30044                          Mayor Office Toronto
# 6   4b06ef4cf964a52072f322e3                            Cafe On The Square
# 7   4c50577d3a6f2d7ff1cc6877                                Farmers Market
# 8   4e332ea1b3ad90171c62f2e3                              Bike Share Stand
# 9   50885719498ea7b5aab3a74c  GoodLife Fitness Toronto Bell Trinity Centre
# 10  4c8938c8944e224b52e72285                        Toronto Public Library
# ...

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                             name                categories  \
# 0        City of Toronto Civic Innovation Office                 City Hall
# 1                              Toronto City Hall                 City Hall
# 2                         Kew Gardens Playground                Playground
# 3                    City Hall Podium Green Roof                    Garden
# 4                     City Hall Council Chambers                 City Hall
# 5                           Mayor Office Toronto                    Office
# 6                             Cafe On The Square                Restaurant
# 7                                 Farmers Market            Farmers Market
# 8                               Bike Share Stand  Bike Rental / Bike Share
# 9   GoodLife Fitness Toronto Bell Trinity Centre                       Gym
# 10                        Toronto Public Library                   Library
# ...

# %%
dataframe_filtered.name
# Out:
# 0          City of Toronto Civic Innovation Office
# 1                                Toronto City Hall
# 2                           Kew Gardens Playground
# 3                      City Hall Podium Green Roof
# 4                       City Hall Council Chambers
# 5                             Mayor Office Toronto
# 6                               Cafe On The Square
# 7                                   Farmers Market
# 8                                 Bike Share Stand
# 9     GoodLife Fitness Toronto Bell Trinity Centre
# 10                          Toronto Public Library
# 11                Nathan Philips Square Playground
# 12                                     Bubble Baby
# 13                           Hydro One Head Office
# 14                                            CIBC
# 15                                  Service Canada
# 16                   Starbucks (Market at Longo's)
# 17                            Jack Layton Memorial
# ...

# %%
df_out['latitude'] = df_out['latitude'].astype(str).astype(float)
df_out['longitude'] = df_out['longitude'].astype(str).astype(float)

# %%
df_out.head()
# Out:
#                locationName                locationType  \
# 31         DEMARCO PHARMACY  Pharmacy Immunization Site
# 32      GLEN PARK PHARMACY*  Pharmacy Immunization Site
# 33            SHIH PHARMACY  Pharmacy Immunization Site
# 34          LAROSE PHARMACY  Pharmacy Immunization Site
# 35  PHARMA TRUST DRUG MART*  Pharmacy Immunization Site
#
#                     address       city postal_code  \
# 31            2394 KEELE ST    Toronto     M6M 4A5
# 32         2920 DUFFERIN ST    Toronto     M6B 3S8
# 33  2700 KIPLING AVE UNIT 9    Rexdale     M9V 4P2
# 34           140 LAROSE AVE     Weston     M9P 1B2
# 35      1935 SHEPPARD AVE W  Downsview     M3L 1Y8
#
#                                                 hours  \
# 31  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 32  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 33  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 34  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# ...

# %%
df_out.drop
# Out:
# <bound method DataFrame.drop of                  locationName                locationType  \
# 31           DEMARCO PHARMACY  Pharmacy Immunization Site
# 32        GLEN PARK PHARMACY*  Pharmacy Immunization Site
# 33              SHIH PHARMACY  Pharmacy Immunization Site
# 34            LAROSE PHARMACY  Pharmacy Immunization Site
# 35    PHARMA TRUST DRUG MART*  Pharmacy Immunization Site
# ..                        ...                         ...
# 302        Nhatrang Drug Mart  Pharmacy Immunization Site
# 303      Weston jane Pharmacy  Pharmacy Immunization Site
# 304         Lakeside Pharmacy  Pharmacy Immunization Site
# 305  I CARE Pharmacy Services  Pharmacy Immunization Site
# 306          Lapsley Pharmacy  Pharmacy Immunization Site
#
#                                   address       city postal_code  \
# 31                          2394 KEELE ST    Toronto     M6M 4A5
# 32                       2920 DUFFERIN ST    Toronto     M6B 3S8
# ...

# %%
m = folium.Map(location=[latitude, longitude], tiles='openstreetmap', zoom_start=15)

# Add points to the map
for idx, row in df_out.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['locationName']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
m = folium.Map(location=[latitude, longitude], tiles='openstreetmap')
for lat, lng in zip(df_out.latitude, df_out.longitude):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        #popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
from folium import plugins

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# %%
df_out2 = df_out[['latitude','longitude']]

# %%
distortions = []
K = range(1,20)
for k in K:
    kmean = KMeans(n_clusters=k, random_state=0, n_init = 50, max_iter = 500)
    kmean.fit(df_out2)
    distortions.append(kmean.inertia_)

# %%
df_out2.head()
# Out:
#      latitude  longitude
# 31  43.707918 -79.478257
# 32  43.708747 -79.453862
# 33  43.756693 -79.589314
# 34  43.685625 -79.523950
# 35  43.738836 -79.511500

# %%
df_out.head()
# Out:
#                locationName                locationType  \
# 31         DEMARCO PHARMACY  Pharmacy Immunization Site
# 32      GLEN PARK PHARMACY*  Pharmacy Immunization Site
# 33            SHIH PHARMACY  Pharmacy Immunization Site
# 34          LAROSE PHARMACY  Pharmacy Immunization Site
# 35  PHARMA TRUST DRUG MART*  Pharmacy Immunization Site
#
#                     address       city postal_code  \
# 31            2394 KEELE ST    Toronto     M6M 4A5
# 32         2920 DUFFERIN ST    Toronto     M6B 3S8
# 33  2700 KIPLING AVE UNIT 9    Rexdale     M9V 4P2
# 34           140 LAROSE AVE     Weston     M9P 1B2
# 35      1935 SHEPPARD AVE W  Downsview     M3L 1Y8
#
#                                                 hours  \
# 31  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 32  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 33  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 34  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
import seaborn as sns; sns.set()
import csv

# %%
X=df_out.loc[:,['latitude','longitude']]

# %%
K_clusters = range(1,10)

kmeans = [KMeans(n_clusters=i) for i in K_clusters]

Y_axis = df_out[['latitude']]
X_axis = df_out[['longitude']]

score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]

# %%
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')

plt.ylabel('Score')

plt.title('Elbow Curve')

plt.show()

# %%
X.head()
# Out:
#      latitude  longitude
# 31  43.707918 -79.478257
# 32  43.708747 -79.453862
# 33  43.756693 -79.589314
# 34  43.685625 -79.523950
# 35  43.738836 -79.511500

# %%
kmeans = KMeans(n_clusters = 3, init ='k-means++')
kmeans.fit(X[X.columns[0:3]]) # Compute k-means clustering. # Compute k-means clustering.

X['cluster_label'] = kmeans.fit_predict(X[X.columns[0:2]])

centers = kmeans.cluster_centers_ # Coordinates of cluster centers.

labels = kmeans.predict(X[X.columns[0:2]]) # Labels of each point

X.head(40)
# Out:
#      latitude  longitude  cluster_label
# 31  43.707918 -79.478257              0
# 32  43.708747 -79.453862              0
# 33  43.756693 -79.589314              0
# 34  43.685625 -79.523950              0
# 35  43.738836 -79.511500              0
# 36  43.686772 -79.483768              0
# 37  43.735378 -79.348044              2
# 38  43.758779 -79.315140              1
# 39  43.734787 -79.419562              2
# 40  43.688675 -79.390362              2
# 41  43.667223 -79.381252              2
# 42  43.772976 -79.321140              1
# 43  43.663087 -79.374563              2
# 44  43.702148 -79.522438              0
# 45  43.669556 -79.301458              2
# 46  43.656558 -79.376157              2
# 47  43.651022 -79.475790              0
# 48  43.643375 -79.447413              0
# 49  43.721575 -79.596043              0
# 50  43.722677 -79.416300              2
# 51  43.683957 -79.322265              2
# 52  43.630166 -79.481551              0
# ...

# %%
X.plot.scatter(x = 'latitude', y = 'longitude', c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[ 43.6810794  -79.50334476]
#  [ 43.76707456 -79.26062953]
#  [ 43.69105775 -79.3858779 ]]

# %%
df_out.head()
# Out:
#                locationName                locationType  \
# 31         DEMARCO PHARMACY  Pharmacy Immunization Site
# 32      GLEN PARK PHARMACY*  Pharmacy Immunization Site
# 33            SHIH PHARMACY  Pharmacy Immunization Site
# 34          LAROSE PHARMACY  Pharmacy Immunization Site
# 35  PHARMA TRUST DRUG MART*  Pharmacy Immunization Site
#
#                     address       city postal_code  \
# 31            2394 KEELE ST    Toronto     M6M 4A5
# 32         2920 DUFFERIN ST    Toronto     M6B 3S8
# 33  2700 KIPLING AVE UNIT 9    Rexdale     M9V 4P2
# 34           140 LAROSE AVE     Weston     M9P 1B2
# 35      1935 SHEPPARD AVE W  Downsview     M3L 1Y8
#
#                                                 hours  \
# 31  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 32  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 33  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# 34  Monday: , Tuesday: , Wednesday: , Thursday: , ...
# ...

# %%
df_out['hours'].unique()
# Out:
# array(['Monday: , Tuesday: , Wednesday: , Thursday: , Friday: , Saturday: , Sunday:',
#        'Monday: 10 a.m.-7 p.m., Tuesday: 10 a.m.-7 p.m., Wednesday: 10 a.m.-7 p.m., Thursday: 10 a.m.-7 p.m., Friday: 10 a.m.-7 p.m., Saturday: 10 a.m.-3 p.m., Sunday: closed',
#        'Monday: 9 a.m.-6 p.m., Tuesday: 9 a.m.-6 p.m., Wednesday: 9 a.m.-6 p.m., Thursday: 9 a.m.-6 p.m., Friday: 9 a.m.-6 p.m., Saturday: 9 a.m.-4 p.m., Sunday: closed',
#        'Monday: 9.30-17:00, Tuesday: 9.30-17:00, Wednesday: 9.30-17:00, Thursday: 9.30-17:00, Friday: 9.30-17:00, Saturday: 10 a.m.-2 p.m., Sunday:',
#        'Monday: 9 a.m.-6 p.m., Tuesday: 9 a.m.-6 p.m., Wednesday: 9 a.m.-6 p.m., Thursday: 9 a.m.-6 p.m., Friday: 9 a.m.-6 p.m., Saturday: 10 a.m.-4 p.m., Sunday: Closed',
#        'Monday: 9:30 a.m.-6:30 p.m., Tuesday: 9:30 a.m.-6:30 p.m., Wednesday: 9:30 a.m.-6:30 p.m., Thursday: 9:30 a.m.-6:30 p.m., Friday: 9:30 a.m.-6:30pm, Saturday: 10 a.m.-1 p.m., Sunday: 10.00-1.00',
# ...
